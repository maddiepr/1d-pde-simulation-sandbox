# %% [markdown]
# # Reaction-Diffusion Simulation Visualization
#
# This notebook loads simulation output from 'data/' and visualizes the final particle distributions.
# It compares Monte Carlo results to analytical solutions where available.
#
# Steps:
# 1. Load particle positions and weights from '.npy' files
# 2. Generate weighted histograms
# 3. Plot and compare with exact or expected densities

# %%
# --- Setup path and utilities ---
import sys
from pathlib import Path

project_root = Path("..").resolve()
sys.path.insert(0, str(project_root))

from src.plotting import plot_and_save_all_histograms
print(project_root)
# Out:
# C:\Users\Maddie\1d-pde-simulation-sandbox\1d-pde-simulation-sandbox

# %%
reaction_base = Path("../data/reaction")
reaction_out = Path("../docs/reaction")

plot_and_save_all_histograms(
    base_dir=reaction_base,
    output_dir=reaction_out,
    title_prefix="Reaction: ",
    show_one=True,
    bins=100,
    histogram_color="skyblue",
    exact_solution="reaction",
    exact_label = "Exact",
    exact_color = "red"
)
# Out:
# Processing: T1.0_D1.0_alpha1.0_x0_-2.0
# Saved to: ..\docs\reaction\T1.0_D1.0_alpha1.0_x0_-2.0.png
# Processing: T1.0_D1.0_alpha1.0_x0_1.0
# Saved to: ..\docs\reaction\T1.0_D1.0_alpha1.0_x0_1.0.png
# Processing: T1.0_D2.0_alpha1.0_x0_-2.0
# Saved to: ..\docs\reaction\T1.0_D2.0_alpha1.0_x0_-2.0.png
# Processing: T1.0_D2.0_alpha1.0_x0_1.0
# Saved to: ..\docs\reaction\T1.0_D2.0_alpha1.0_x0_1.0.png

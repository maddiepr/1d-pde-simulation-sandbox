# %% [markdown]
# # Advection-Diffusion Simulation Visualization
#
# This notebooks loads and visualizes output from the 1D advection-diffusion Monte Carlo simulation.
#
# Steps:
# 1. Load final particle positions and weights from the 'data/' directory
# 2. Generate weighted histograms of particle density
# 3. Compare results to analytical or expected drift-based solutions

# %%
# --- Setup path and utilities ---

# --- Setup path and utilities ---
import sys
from pathlib import Path

project_root = Path("..").resolve()
sys.path.insert(0, str(project_root))

from src.plotting import plot_and_save_all_histograms
print(project_root)
# Out:
# C:\Users\Maddie\1d-pde-simulation-sandbox\1d-pde-simulation-sandbox

# %%
# --- List avaibable folders ---
reaction_base = Path("../data/advection")
reaction_out = Path("../docs/advection")

plot_and_save_all_histograms(
    base_dir=reaction_base,
    output_dir=reaction_out,
    title_prefix="Advection: ",
    show_one=True,
    bins=100,
    histogram_color="skyblue",
    exact_solution="advection",
    exact_label = "Exact",
    exact_color = "red"
)
# Out:
# Processing: T0.0_D1.0_alpha0.5_x0_-2.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       2 reaction_base = Path("../data/advection")
#       3 reaction_out = Path("../docs/advection")
# ----> 5 plot_and_save_all_histograms(
#       6     base_dir=reaction_base,
#       7     output_dir=reaction_out,
#       8     title_prefix="Advection: ",
#       9     show_one=True,
#      10     bins=100,
#      11     histogram_color="skyblue",
#      12     exact_solution="advection",
#      13     exact_label = "Exact",
#      14     exact_color = "red"
#      15 )
#
# File ~\1d-pde-simulation-sandbox\1d-pde-simulation-sandbox\src\plotting.py:122, in plot_and_save_all_histograms(base_dir, output_dir, title_prefix, show_one, bins, range, exact_solution, exact_label, exact_color, histogram_color)
#     120 T_val = params['T']
#     121 D_val = params['D']
# ...
